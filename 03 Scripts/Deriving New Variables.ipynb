# %% [markdown]
# # Deriving New Variables

# %%
import pandas as pd
import numpy as np 
import os

# %%
path = r'C:\Users\mosh_\OneDrive\Desktop\Career Foundry\Data Immersion\Achievement 4 - Python Fundemental For Data Analyst'

# %%
path
# Out:
# 'C:\\Users\\mosh_\\OneDrive\\Desktop\\Career Foundry\\Data Immersion\\Achievement 4 - Python Fundemental For Data Analyst'

# %%
df_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
df_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_derived.pkl'))

# %%
df = df_merged[:1000000]

# %%
df
# Out:
#         order_id  user_id eval_set  order_number  orders_day_of_the_week  \
# 0        2539329        1    prior             1                       2
# 1        2539329        1    prior             1                       2
# 2        2539329        1    prior             1                       2
# 3        2539329        1    prior             1                       2
# 4        2539329        1    prior             1                       2
# ...          ...      ...      ...           ...                     ...
# 999995   2789027     6474    prior             2                       3
# 999996   2789027     6474    prior             2                       3
# 999997   2789027     6474    prior             2                       3
# 999998   2789027     6474    prior             2                       3
# 999999   2789027     6474    prior             2                       3
#
#         order_hour_of_day  days_since_last_order  product_id  \
# ...

# %% [markdown]
# #### implementing a If statement on the price

# %%
## arranging price in 3 categories

# %%
def price_label(row):
    
    if row['prices'] <= 5:
        return 'Low-Range Product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-Range Product' 
    elif row['prices'] > 15:
        return ' High-Range Product'
    else: return ' Not enough data'

# %%
## applying the function to the dataset

# %%
df['Price_range'] = df.apply(price_label, axis=1)

# %%
df
# Out:
#         order_id  user_id eval_set  order_number  orders_day_of_the_week  \
# 0        2539329        1    prior             1                       2
# 1        2539329        1    prior             1                       2
# 2        2539329        1    prior             1                       2
# 3        2539329        1    prior             1                       2
# 4        2539329        1    prior             1                       2
# ...          ...      ...      ...           ...                     ...
# 999995   2789027     6474    prior             2                       3
# 999996   2789027     6474    prior             2                       3
# 999997   2789027     6474    prior             2                       3
# 999998   2789027     6474    prior             2                       3
# 999999   2789027     6474    prior             2                       3
#
#         order_hour_of_day  days_since_last_order  product_id  \
# ...

# %%
df['Price_range'].value_counts()
# Out:
# Price_range
# Mid-Range Product      673183
# Low-Range Product      314392
#  High-Range Product     12425
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# IF statement with the LOC Function

# %%
## arranging price based on LOC. using it on the subset DF of 1,000,000

# %%
df.loc[df['prices']> 15, 'price_range_loc'] = 'High-Range product'

# %%
df.loc[(df['prices']<= 15) & (df['prices']> 5), 'price_range_loc'] = 'Mid- Range product'

# %%
df.loc[df['prices']< 5, 'price_range_loc'] = 'Low-Range product'

# %%
df
# Out:
#         order_id  user_id eval_set  order_number  orders_day_of_the_week  \
# 0        2539329        1    prior             1                       2
# 1        2539329        1    prior             1                       2
# 2        2539329        1    prior             1                       2
# 3        2539329        1    prior             1                       2
# 4        2539329        1    prior             1                       2
# ...          ...      ...      ...           ...                     ...
# 999995   2789027     6474    prior             2                       3
# 999996   2789027     6474    prior             2                       3
# 999997   2789027     6474    prior             2                       3
# 999998   2789027     6474    prior             2                       3
# 999999   2789027     6474    prior             2                       3
#
#         order_hour_of_day  days_since_last_order  product_id  \
# ...

# %%
df['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Mid- Range product    673183
# Low-Range product     307024
# High-Range product     12425
# Name: count, dtype: int64

# %%
## This matches the value when creating the if Statement

# %% [markdown]
# #### Loc function on the ords_prods_merge df

# %%
df_merged.loc[df_merged['prices']> 15, 'price_range_loc'] = 'High-Range product'

# %%
df_merged.loc[(df_merged['prices']<= 15) & (df['prices']> 5), 'price_range_loc'] = 'Mid- Range product'

# %%
df_merged.loc[df_merged['prices']< 5, 'price_range_loc'] = 'Low-Range product'

# %%
df_merged['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Low-Range product     9900417
# Mid- Range product     673183
# High-Range product     417678
# Name: count, dtype: int64

# %% [markdown]
# #### For loops

# %%
## finding the busiest day of the year

# %%
df_merged['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# orders_day_of_the_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
## creating a loop for the busiest and least busiest day of the week

# %%
result = []
for value in df_merged['orders_day_of_the_week']:
    if value == 0 :
        result.append("busiest day")
    elif value == 4:
        result.append("least busy")
    else:
        result.append("Regular busy")

# %%
## adding the result to the merged dataset

# %%
df_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regular busy    22416875
# busiest day      6204182
# least busy       3783802
# Name: count, dtype: int64

# %% [markdown]
# #### identifying the two busiest and slowest days of the week

# %%
df_merged['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# orders_day_of_the_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
## 0 and 1 are the busiest days of the week while 3 and 4 are the slowest days

# %% [markdown]
# #### Deriving new columns for 2 busiest and 2 least busiest days

# %%
result2= []

for value in df_merged['orders_day_of_the_week']:
    if value == 0 or value == 1:
        result2.append("busiest days")
    elif value == 4 or value == 3:
        result2.append("slowest days")
    else:
        result2.append("Normal busy")

# %%
##  updating the current busiest day column with new results

# %%
df_merged['busiest_day'] = result2

# %%
df_merged
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_the_week  \
# 0          2539329        1    prior             1                       2
# 1          2539329        1    prior             1                       2
# 2          2539329        1    prior             1                       2
# 3          2539329        1    prior             1                       2
# 4          2539329        1    prior             1                       2
# ...            ...      ...      ...           ...                     ...
# 32404854   2977660   206209    prior            13                       1
# 32404855   2977660   206209    prior            13                       1
# 32404856   2977660   206209    prior            13                       1
# 32404857   2977660   206209    prior            13                       1
# 32404858   2977660   206209    prior            13                       1
#
#           order_hour_of_day  days_since_last_order  product_id  \
# ...

# %%
df_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Normal busy     12916111
# busiest days    11864412
# slowest days     7624336
# Name: count, dtype: int64

# %% [markdown]
# #### Busiest periods of the day

# %%
## Identify what times of day is the busiest

# %%
df_merged['order_hour_of_day'].value_counts( dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
## Dividing the busiest time into 3 sections

# %%
result3=[]

for value in df_merged['order_hour_of_day']:
    if value in [10, 11, 14, 15, 13, 12, 16, 9]:
        result3.append("Most Orders")
    elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
        result3.append("Fewest Orders") 
    else:
        result3.append("Average orders")

# %%
## inserting the busiest time into the merged df

# %%
df_merged['busiest_period_of_day'] = result3

# %%
df_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most Orders       21118071
# Average orders     9997651
# Fewest Orders      1289137
# Name: count, dtype: int64

# %%
df_merged.to_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'ords_prods_merge_derived.pkl'))
